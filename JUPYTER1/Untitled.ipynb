# %%
import matplotlib.pyplot as plt

# This is to see the plot inside the notebook
# %matplotlib inline

x = list(range(0,10))
y = list(range(-10,0))

plt.plot(x,y)

# %%
a = [0,-100,25,67,-323]
b = [0,3,7,3,9]

plt.plot(a,b)

# %%
plt.axis([])
